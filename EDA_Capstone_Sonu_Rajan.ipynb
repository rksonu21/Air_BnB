# %% [markdown]
# #  ***Airbnb EDA Analysis***

# %% [markdown]
# #### **Project Type**    - Exploratory Data Analysis
# #### **Contribution**    - Sonu Rajan (Cohort Manila)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
#import all library that will be used in entire project
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 7)
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
bnb_df=pd.read_csv('Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
bnb_df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
dataset_rows=print(len(bnb_df))
columns_count=print(len(bnb_df.columns))
# Out:
# 48895
# 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
bnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
bnb_df.duplicated(keep=False).sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
bnb_df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
# Calculate missing value frequencies
missing_counts = bnb_df.isnull().sum()

# Plotting the frequency of missing values
plt.figure(figsize=(25, 10))
plt.bar(missing_counts.index, missing_counts.values)
plt.title('Missing Values - Frequency Plot')
plt.xlabel('Columns')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# From the above dataset it was seen that the majority of the datatypes in the given dataset is categorical, and some of the numerical entries in the dataset are also unique in nature. Hence any form of analytics on them for potential pattern recognition is futile. The best way to approach the data problem is to perform analytical operations on the categorical values and look try and decipher consumer behaviour- or potential behavioural similarities- using the demographical inputs and price signals.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
bnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
bnb_df.describe(include=['int64','float64'])
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in bnb_df.columns:
    unique_values = bnb_df[column].nunique()
    print(f"Unique values in {column}: {unique_values}")
# Out:
# Unique values in id: 48895
# Unique values in name: 47905
# Unique values in host_id: 37457
# Unique values in host_name: 11452
# Unique values in neighbourhood_group: 5
# Unique values in neighbourhood: 221
# Unique values in latitude: 19048
# Unique values in longitude: 14718
# Unique values in room_type: 3
# Unique values in price: 674
# Unique values in minimum_nights: 109
# Unique values in number_of_reviews: 394
# Unique values in last_review: 1764
# Unique values in reviews_per_month: 937
# Unique values in calculated_host_listings_count: 47
# Unique values in availability_365: 366

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#Remove latitude, longitude, last_review and reviews_per_month columns from original dataset
bnb_df.drop(bnb_df.columns[[6,7,12,13]], axis=1, inplace=True)

# %%
#we apply dropna() function to entire dataset and drop null values with dropna() function 
airbnb_df = bnb_df.dropna()

#Information about our new non null dataframe
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48858 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48858 non-null  int64
#  1   name                            48858 non-null  object
#  2   host_id                         48858 non-null  int64
#  3   host_name                       48858 non-null  object
#  4   neighbourhood_group             48858 non-null  object
#  5   neighbourhood                   48858 non-null  object
#  6   room_type                       48858 non-null  object
#  7   price                           48858 non-null  int64
#  8   minimum_nights                  48858 non-null  int64
#  9   number_of_reviews               48858 non-null  int64
#  10  calculated_host_listings_count  48858 non-null  int64
#  11  availability_365                48858 non-null  int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %%
# Function to remove outliers using IQR method
def remove_outliers(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    cleaned_data = data[(data >= lower_bound) & (data <= upper_bound)]
    return cleaned_data

# Create subplots for each variable after removing outliers
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Create boxplots for each variable after removing outliers
for i, col in enumerate(bnb_df.columns[[7,8,9,11]]):
    cleaned_data = remove_outliers(bnb_df[col])
    sns.boxplot(x=cleaned_data, ax=axes[i])
    axes[i].set_title(f'Boxplot of {col} (After Outlier Removal)')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
#Unstack the group by information for plot the graph
avg_preffered_price_df = airbnb_df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
avg_preffered_price_df
#Graph of average price of property according to location
avg_preffered_price_df.plot.bar()
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart chosen here is a Bar Chart which is particularly good in representing numerical information for specific categorical classes. Here in the given chart, we can deduce the average price of rooms in all the five neighborhood groups in New York City. Moreover, we can add granularity to the information presented by adding categories of room types according to their average prices in their respective neighborhood groups. This added level of nuance in visualization can only be achieved using a Bar Chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see that Manhatten is the most expensive Air BnB host in New York. It can be understood by the fact that it is predominantly the financial hub of New York and home to Wall Street and the NYSE, this means that the visitors it generally attracts are traveling business professionals. We can also assume safely that since business trips are open-ended it can lead to a higher demand for entire homes/apts. The high prices testify to the fact that the consumer base is financially affluent.
#
# Brooklyn, Queens, and Staten Island have roughly the same price profile. It can be safely asserted that Airbnb users are more or less indifferent towards choosing to stay at any of these neighborhood groups.
#
# The Bronx has a lower average price when compared to the other boroughs for its Air Bnbs, be it in any category Entire Room, Private Room, or Shared Room because it is deemed to be the most unsafe of all the boroughs in New York City, and maybe it that is why it not able to attract any clientele for it's Air Bnbs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# <i>Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The most valuable insight that can drive positive business growth is the strategy to include more Bnbs in areas having good connectivity to Manhatten and its allied economic centers. As New York experiences a lot of business travelers, it will be of great business value to connect the Bnbs from other boroughs to absorb the excessive Manhatten footfall.
# This can be done by acquiring properties nearby Manhatten from other boroughs and using them for a pricing premium as their connectivity to Manhatten can significantly improve their price valuations.

# %% [markdown]
# #### Chart - 2

# %%
#Apply group by operation on neighbourhood_group for find the number of host according to location
no_of_host_per_location = airbnb_df.groupby('neighbourhood_group',as_index=False)['host_id'].count().sort_values(['host_id'], ascending=False).rename(columns={'neighbourhood_group':'Location','host_id':'Host'})
no_of_host_per_location
# Out:
#         Location   Host
# 2      Manhattan  21643
# 1       Brooklyn  20089
# 3         Queens   5664
# 0          Bronx   1089
# 4  Staten Island    373

# %%
#Take a simple format of above question without index for plot the line chart
no_of_host_per_location = airbnb_df.groupby('neighbourhood_group')['host_id'].count()
no_of_host_per_location
# Out:
# neighbourhood_group
# Bronx             1089
# Brooklyn         20089
# Manhattan        21643
# Queens            5664
# Staten Island      373
# Name: host_id, dtype: int64

# %%
#Graph
plt.legend(labels = ['No. of Host'])
plt.plot(no_of_host_per_location)
plt.title('Number of host per location')
plt.ylabel('Host')
plt.xlabel('Neighbourhood Location')
# Out:
# Text(0.5, 0, 'Location')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The below chart is an example of a line chart which is generally used to demonstrate numerical values. Numerical values over categories can also be well-represented in a line chart as the movements along the line chart can help in establishing the higher and lower numerical values among categories concerning the upward or downward direction of the line. Also, line charts are exceptionally helpful in plotting a numerical metric over time thus making it of great value while performing trend analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It can be seen via the line chart above that Manhattan and Brooklyn have the highest number of hosts. Queens and Bronx have a significant number of hosts which can be attributed to their cultural value and their reputation for being the artistic hub of New York City.
# Staten Island is a comparatively separated borough from New York, as it is across the Hudson River. The geographical location of Staten Island itself makes it inaccessible thus it can be a reason for a lower number of hosts in Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Since we know which boroughs of New York City have a lower number of Airbnb hosts, namely Queens, Bronx, and Staten Island we can tweak the business model by incentivizing the real-estate owners in these neighborhoods to nudge them into turning their spare real estate space into an Airbnb if the demand for them is adequate in those areas. Since these areas fall in the middle/lower-middle income neighborhood groups one can provide them with financial assistance in renovating their property especially if they are looking to turn it into an Airbnb.

# %% [markdown]
# #### Chart - 4

# %%
#Creating DataFrame
count_host_id = list(airbnb_df['host_id'].value_counts())
host_id = list(airbnb_df.host_id)
listing_count= list(zip(host_id,count_host_id))
count_host_id_df= pd.DataFrame(listing_count)
count_host_id_df.rename(columns={0:'Host_Id',1:'Counts'},inplace=True)

#Storing top 10 hosts with most listings
top_host_id = count_host_id_df.head(10)
top_host_id
# Out:
#    Host_Id  Counts
# 0     2787     327
# 1     2845     232
# 2     4632     121
# 3     4869     103
# 4     7192      96
# 5     7322      96
# 6     7356      91
# 7     8967      87
# 8     7490      65
# 9     7549      52

# %%
#Setting the figure size
sns.set(rc={'figure.figsize':(10,8)})

#Setting background colour of chart as white
sns.set_style('white')

#Plotting the Chart
viz_bar = sns.barplot(x= 'Host_Id', y= 'Counts', color='r', data=top_host_id,
                      order=top_host_id.sort_values('Counts',ascending = False).Host_Id)

#Setting font size for title
sns.set(font_scale = 2)

# Naming the Chart
viz_bar.set_title('Hosts with most listings in New York')

# Naming X & Y axis
viz_bar.set_xlabel('Host IDs')
viz_bar.set_ylabel('Count of listings')

#Adjusting Bar labels
viz_bar.set_xticklabels(viz_bar.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '2787'),
#  Text(1, 0, '2845'),
#  Text(2, 0, '4632'),
#  Text(3, 0, '4869'),
#  Text(4, 0, '7192'),
#  Text(5, 0, '7322'),
#  Text(6, 0, '7356'),
#  Text(7, 0, '8967'),
#  Text(8, 0, '7490'),
#  Text(9, 0, '7549')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# find unique value of room types
list(airbnb_df['room_type'].unique())
# Out:
# ['Private room', 'Entire home/apt', 'Shared room']

# %%
#  find the maximum(minimum nights) spending by customer across different room type
total_room=airbnb_df.groupby(  'room_type')['minimum_nights'].sum().reset_index()
room_types=total_room.sort_values('minimum_nights',ascending=True)
room_types.head()
# Out:
#          room_type  minimum_nights
# 2      Shared room            7510
# 1     Private room          120023
# 0  Entire home/apt          215081

# %%
# create dataset
labels=list(room_types['room_type'])
sizes=list(room_types['minimum_nights'])
# create color parameter
colors=['green','pink','yellow']
# create explode
explode = (0.07, 0.07, 0.07)

# %%
#creating pie chart
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.title('total no. of nights spend per room types', fontsize=20)
plt.axis("equal")  
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# find listing value of all neighourhood in dataset
neighour=airbnb_df['neighbourhood'].value_counts().sort_values(ascending=False).reset_index()
#top ten neighourhood with listing value
top_10=neighour[:10]
top_10
# Out:
#                 index  neighbourhood
# 0        Williamsburg           3917
# 1  Bedford-Stuyvesant           3713
# 2              Harlem           2655
# 3            Bushwick           2462
# 4     Upper West Side           1969
# 5      Hell's Kitchen           1954
# 6        East Village           1852
# 7     Upper East Side           1797
# 8       Crown Heights           1563
# 9             Midtown           1545

# %%
#make copy of top_10
final_10=top_10.copy()
#rename that dataframe
final_10.rename(columns={'index':'neighourhood','neighbourhood':'listing_value' },inplace=True)

final_10
# Out:
#          neighourhood  listing_value
# 0        Williamsburg           3917
# 1  Bedford-Stuyvesant           3713
# 2              Harlem           2655
# 3            Bushwick           2462
# 4     Upper West Side           1969
# 5      Hell's Kitchen           1954
# 6        East Village           1852
# 7     Upper East Side           1797
# 8       Crown Heights           1563
# 9             Midtown           1545

# %%
# data visualizing with barplot
sns.set(rc={'figure.figsize':(15,10)})
sns.set_style('white')
#Plotting the Chart
abc= sns.barplot(x='neighourhood', y='listing_value',data = final_10)
abc.set_title('find total no. nights spend per location')
# Naming X & Y axis
abc.set_ylabel('listing value')
abc.set_xlabel('neighourhood')
#Adjusting Bar labels

abc.set_xticklabels(abc.get_xticklabels(),rotation = 45,size='15')
# Out:
# [Text(0, 0, 'Williamsburg'),
#  Text(1, 0, 'Bedford-Stuyvesant'),
#  Text(2, 0, 'Harlem'),
#  Text(3, 0, 'Bushwick'),
#  Text(4, 0, 'Upper West Side'),
#  Text(5, 0, "Hell's Kitchen"),
#  Text(6, 0, 'East Village'),
#  Text(7, 0, 'Upper East Side'),
#  Text(8, 0, 'Crown Heights'),
#  Text(9, 0, 'Midtown')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
#Creting empty list to store name strings
airbnb_names=[]

#Getting name string from 'name' column and appending it to the empty list
for name in airbnb_df.name:
    airbnb_names.append(name)

#Setting a function to split name strings into seperate words
def split_name(name):
    ns = str(name).split()
    return ns

#Creating empty list to store the count of words
names_count = []

#Getting name string to append it to the names_count list
for n in airbnb_names:
    for word in split_name(n):
        word = word.lower()
        names_count.append(word)

# %%
# Importing 'counter' library to count and generate raw data and count top 25 most used words
from collections import Counter

# Counting most common words
count_words = Counter(names_count).most_common()
count_words[:25]
# Out:
# [('in', 16723),
#  ('room', 9383),
#  ('bedroom', 7226),
#  ('private', 6983),
#  ('apartment', 6112),
#  ('cozy', 4631),
#  ('the', 3866),
#  ('to', 3826),
#  ('studio', 3770),
#  ('brooklyn', 3629),
#  ('apt', 3571),
#  ('spacious', 3383),
#  ('1', 3355),
#  ('with', 3092),
#  ('2', 3078),
#  ('of', 2992),
#  ('east', 2966),
#  ('and', 2868),
#  ('manhattan', 2854),
#  ('&', 2820),
#  ('park', 2631),
#  ('sunny', 2535),
#  ('beautiful', 2319),
#  ('near', 2293),
#  ('williamsburg', 2292)]

# %%
# Cleaning the List by removing prepositions
items_to_remove = {('in', 16733), ('the', 3869), ('to', 3827), ('of', 2993), ('-', 2272), ('a', 1909)}
top_25_cleaned = [e for e in count_words if e not in items_to_remove]
top_25 = top_25_cleaned[:25]
top_25
# Out:
# [('in', 16723),
#  ('room', 9383),
#  ('bedroom', 7226),
#  ('private', 6983),
#  ('apartment', 6112),
#  ('cozy', 4631),
#  ('the', 3866),
#  ('to', 3826),
#  ('studio', 3770),
#  ('brooklyn', 3629),
#  ('apt', 3571),
#  ('spacious', 3383),
#  ('1', 3355),
#  ('with', 3092),
#  ('2', 3078),
#  ('of', 2992),
#  ('east', 2966),
#  ('and', 2868),
#  ('manhattan', 2854),
#  ('&', 2820),
#  ('park', 2631),
#  ('sunny', 2535),
#  ('beautiful', 2319),
#  ('near', 2293),
#  ('williamsburg', 2292)]

# %%
#converting the data into DataFrame
word_count_df = pd.DataFrame(top_25)
word_count_df.rename(columns={0:'Words',1:'Counts'},inplace=True)
word_count_df
# Out:
#            Words  Counts
# 0             in   16723
# 1           room    9383
# 2        bedroom    7226
# 3        private    6983
# 4      apartment    6112
# 5           cozy    4631
# 6            the    3866
# 7             to    3826
# 8         studio    3770
# 9       brooklyn    3629
# 10           apt    3571
# 11      spacious    3383
# 12             1    3355
# 13          with    3092
# 14             2    3078
# 15            of    2992
# 16          east    2966
# 17           and    2868
# 18     manhattan    2854
# 19             &    2820
# 20          park    2631
# 21         sunny    2535
# 22     beautiful    2319
# 23          near    2293
# 24  williamsburg    2292

# %%
#Importing WordCloud library
from wordcloud import WordCloud, ImageColorGenerator
text = ' '.join(str(n) for n in word_count_df.Words)

#Generating wordcloud image
wordcloud = WordCloud(max_font_size=80, colormap='hsv', width=400, height=150).generate(text)
plt.figure(figsize=(12,8))

#Displaying the image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#  find the maximum price across different host name
top_ng_host_stay=airbnb_df.groupby(['neighbourhood_group'])['minimum_nights'].mean().round().reset_index()
top_ng_host_stay.rename(columns={'minimum_nights':'avg_neighbourhood_stay'},inplace=True)
top_ng_host_stay.head()
# Out:
#   neighbourhood_group  avg_neighbourhood_stay
# 0               Bronx                     5.0
# 1            Brooklyn                     6.0
# 2           Manhattan                     9.0
# 3              Queens                     5.0
# 4       Staten Island                     5.0

# %%
# Create a tree map using squarify
import squarify
colors = ["red", "green", "blue", "pink","yellow"]
squarify.plot(sizes=top_ng_host_stay['avg_neighbourhood_stay'],label=top_nghost['neighbourhood_group'],color=colors, alpha=0.7)
plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
#  find the maximum price across different host name
top_host=airbnb_df.groupby(['host_name','host_id'])['price'].sum().reset_index()
top_host.rename(columns={'price':'total_price'},inplace=True)
top_host.head()
# Out:
#                   host_name   host_id  total_price
# 0                      'Cil  45354224          120
# 1           (Ari) HENRY LEE  40605120          140
# 2  (Email hidden by Airbnb)   5610823          261
# 3  (Email hidden by Airbnb)   7580102          389
# 4  (Email hidden by Airbnb)  11495251          200

# %%
# find top three host best on their turnover
top_3=top_host.sort_values('total_price',ascending=False).iloc[:3,:3]
top_3
# Out:
#           host_name    host_id  total_price
# 33209  Sonder (NYC)  219517861        82795
# 4856     Blueground  107434423        70331
# 31216         Sally  156158778        37097

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.set_style('white')
abc= sns.barplot(x='host_name',y='total_price',data = top_3)
abc.set_title('three hosts based on their turnover')
abc.set_ylabel('host name')
abc.set_xlabel('total price')

abc.set_xticklabels(abc.get_xticklabels(),rotation = 45,size='10')
# Out:
# [Text(0, 0, 'Sonder (NYC)'), Text(1, 0, 'Blueground'), Text(2, 0, 'Sally')]

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#  find the maximum(minimum nights) spending by customer across different neighourhood group
total_nights = airbnb_df.groupby('neighbourhood_group')['minimum_nights'].sum().reset_index()
total_nights['log_sum_minimum_nights'] = total_nights['minimum_nights'].apply(lambda x: np.log1p(x))
final_nights = total_nights.sort_values('log_sum_minimum_nights', ascending=True)
final_nights.head()
# Out:
#   neighbourhood_group  minimum_nights  log_sum_minimum_nights
# 4       Staten Island            1802                7.497207
# 0               Bronx            4971                8.511577
# 3              Queens           29356               10.287286
# 1            Brooklyn          121693               11.709265
# 2           Manhattan          184792               12.126992

# %%
# visualization of total no. nights spend per location using seaborn
sns.set(rc={'figure.figsize':(10,5)})
sns.set_style('white')
abc= sns.barplot(x='neighbourhood_group',y='log_sum_minimum_nights',data = final_nights)
abc.set_title('find total no. nights spend per location')
abc.set_ylabel('log_sum_minimum_nights')
abc.set_xlabel('neighbourhood group')

abc.set_xticklabels(abc.get_xticklabels(),rotation = 45,size='15')
# Out:
# [Text(0, 0, 'Staten Island'),
#  Text(1, 0, 'Bronx'),
#  Text(2, 0, 'Queens'),
#  Text(3, 0, 'Brooklyn'),
#  Text(4, 0, 'Manhattan')]

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#  find the average price across different neighbourhood groups
top_nghost=airbnb_df.groupby(['neighbourhood_group'])['price'].mean().round().reset_index()
top_nghost.rename(columns={'price':'avg_ng_price'},inplace=True)
top_nghost.head()
# Out:
#   neighbourhood_group  avg_ng_price
# 0               Bronx          87.0
# 1            Brooklyn         124.0
# 2           Manhattan         197.0
# 3              Queens         100.0
# 4       Staten Island         115.0

# %%
# Create a tree map using squarify
colors = ["red", "green", "blue", "pink","yellow"]
squarify.plot(sizes=top_nghost['avg_ng_price'],label=top_nghost['neighbourhood_group'], color=colors, alpha=0.7)
plt.axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
